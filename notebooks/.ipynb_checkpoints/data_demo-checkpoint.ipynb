# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.dataloader import FinanceTransactionDataset

dataset = FinanceTransactionDataset("../data/budgetwise_finance_dataset.csv")

print("Dataset size:", len(dataset))
print("Feature columns:", dataset.get_feature_columns())
print("Target column:", dataset.get_target_column())

features, target = dataset[0]

print("Example input:", features)
print("Example target:", target)
# Out:
# Dataset size: 4827
# Feature columns: ['transaction_type_id', 'category_id', 'payment_mode_id', 'amount']
# Target column: target_next_amount
# Example input: tensor([   0.,    9.,    9., 4178.])
# Example target: tensor(679.)

# %%
import pandas as pd

df = pd.read_csv("../data/budgetwise_finance_dataset.csv")
df.head()
# Out:
#   transaction_id user_id        date transaction_type       category amount  \
# 0          T4999    U018  2023-04-25          Expense       Educaton   3888
# 1         T12828    U133  08/05/2022          Expense           rent    649
# 2          T7403    U091    31-12-23           Income      Freelance  13239
# 3         T12350    U097         NaN          Expense            Fod   6299
# 4          T7495    U088  10/28/2022          Expense  entertainment   2287
#
#     payment_mode   location             notes
# 0           card  Ahmedabad     Movie tickets
# 1            NaN  Hyderabad            asdfgh
# 2            Csh        BAN             Books
# 3  Bank Transfer  AHMEDABAD  Electricity bill
# 4           CARD  Hyderabad               NaN

# %% [markdown]
# The model input contains encoded transaction type, encoded category, and transaction amount.
#
# The target for this milestone example is the transaction amount. Later, this can be changed to predict future spending amount or next transaction category using transaction sequences.
